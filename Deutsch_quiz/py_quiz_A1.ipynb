# %% [markdown]
# # Py prog on german vocabulary A1

# %%
import random
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"a1_wortschatz.csv",encoding='UTF-8')#"latin1")
#df = df.set_index(df['Einheit'])
df
# Out:
#      Einheit artikel Wort in Deutsch              Wort in Englisch
# 0          1     NaN         treffen                       to meet
# 1          1     NaN         sammeln                    to collect
# 2          1       s        Gesprach                 conversationn
# 3          1     NaN            Üben                   To practice
# 4          1       e           Übung                      Practice
# 5          1     NaN       bestellen                      to order
# 6          1     NaN        bezahlen                        to pay
# 7          1     NaN          zahlen                        to pay
# 8          1     NaN          zählen                      to count
# 9          1       e           Zahl                         Number
# 10         1       e          Zahlen                       Numbers
# 11         1       r            Saft                         Juice
# 12         1       r          Dialog                      Dialogue
# ...

# %%
def quize():

    ending = 'y'
    
    while (ending != 'n'):
        x=random.randint(0,leng)
        q = df.iloc[x,1]
        ans = df.iloc[x,2]
        user_ans = input("enter the meaning of {} \t: ".format(q))

        if user_ans in str(ans).lower():
            print("correct, excellent job, the answer is\n {}".format(ans) )
            ending = input("again? enter y/n ").lower()
        else:
            print("meh, try again dumbo, \nbtw the answer is \t{}".format(ans) )
            ending = input("again? enter y/n ").lower()

def multichoice():
    leng=945
    a=random.randint(0,leng)
    b=random.randint(0,leng)
    c=random.randint(0,leng)
    d=random.randint(0,leng)

    s= random.randint(1,4)
    if s==1:
        q=  df.iloc[a,2]
        ans = df.iloc[a,3]
    elif s==2:
        q=  df.iloc[b,2]
        ans = df.iloc[b,3]
    elif s==3:
        q=  df.iloc[c,2]
        ans = df.iloc[c,3]
    else:
        q=  df.iloc[d,2]
        ans = df.iloc[d,3]


    print("Which of the following is \t" + q + "\t: ")
    print("your options are" )
    print("A. "+ df.iloc[a,3] + "\t\t\t" + "B. "+ df.iloc[b,3])
    print("C. "+ df.iloc[c,3] + "\t\t\t" + "D. "+ df.iloc[d,3])
    usr_inp = input("enter your choice :\t")
    if usr_inp.lower() == 'a':
        ans_to_chk = df.iloc[a,3]
    elif usr_inp.lower() == 'b':
        ans_to_chk = df.iloc[b,3]
    elif usr_inp.lower() == 'c':
        ans_to_chk = df.iloc[c,3]
    else :
        ans_to_chk = df.iloc[d,3]

    if ans_to_chk == ans:
        print("correct, the answer is\n" + ans)
    else:
        print("meh, try again dumbo, \nbtw the answer is \t" + ans )	
    end__ = input("play again? \t y/n").lower()
    if end__ == 'y' or end__ == "":
        multichoice() 
multichoice()	
#quize()
# Out:
# Which of the following is 	Aufenthaltsgenehmigung	:
# your options are
# A. to jog			B. residency permit
# C. Farmhause			D. to reply
# enter your choice :
# meh, try again dumbo,
# btw the answer is 	residency permit
# play again? 	 y/n
# Which of the following is 	Uhrzeit	:
# your options are
# A. chance			B. time/time of the day
# C. residency permit			D. Market
# enter your choice :
# meh, try again dumbo,
# btw the answer is 	time/time of the day
# play again? 	 y/n
# Which of the following is 	überhaupt	:
# your options are
# A. to rain			B. narrow
# C. Airplane			D. generally/absolutely
# enter your choice :
# correct, the answer is
# generally/absolutely
# play again? 	 y/n
# Which of the following is 	Arztpraxis	:
# your options are
# A. armchair			B. to search
# C. Doctors clinic			D. calm/peace
# enter your choice :
# meh, try again dumbo,
# btw the answer is 	Doctors clinic
# play again? 	 y/n
# Which of the following is 	Kunde	:
# your options are
# A. Idea			B. Editor
# ...
